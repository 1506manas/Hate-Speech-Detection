# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
import re
import nltk
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
from nltk.corpus import stopwords
import string
stopword = stopwords.words("english")

# %%
df = pd.read_csv("Data/twitter_data.csv")
df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df["label"] = df["class"].map({0: "Hate Speech Detected", 1: "Offensive Speech Detected", 2: "Not Hate and Offensive Speech"})
df
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet  \
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                                label
# 0      Not Hate and Offensive Speech
# 1          Offensive Speech Detected
# 2          Offensive Speech Detected
# 3          Offensive Speech Detected
# 4          Offensive Speech Detected
# ...                              ...
# 24778      Offensive Speech Detected
# 24779  Not Hate and Offensive Speech
# 24780      Offensive Speech Detected
# 24781      Offensive Speech Detected
# 24782  Not Hate and Offensive Speech
#
# [24783 rows x 8 columns]

# %%
df = df[['tweet', 'label']]
df
# Out:
#                                                    tweet  \
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                                label
# 0      Not Hate and Offensive Speech
# 1          Offensive Speech Detected
# 2          Offensive Speech Detected
# 3          Offensive Speech Detected
# 4          Offensive Speech Detected
# ...                              ...
# 24778      Offensive Speech Detected
# 24779  Not Hate and Offensive Speech
# 24780      Offensive Speech Detected
# 24781      Offensive Speech Detected
# 24782  Not Hate and Offensive Speech
#
# [24783 rows x 2 columns]

# %%
def clean(text):
    text = text.lower()
    text = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?|(\n)|(\w*\d\w*)", "", text)
    text = re.sub(r'[^\w\s]', '', text)
    text = [word for word in text.split(' ') if word not in (stopword)]
    text = " ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text = " ".join(text)
    return text
df['tweet'] = df['tweet'].apply(clean)
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7524\836832696.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet'] = df['tweet'].apply(clean)
#                                                tweet  \
# 0   rt mayasolov woman shouldnt complain clean ho...
# 1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...
# 2   rt urkindofbrand dawg rt  ever fuck bitch sta...
# 3             rt cganderson vivabas look like tranni
# 4   rt shenikarobert shit hear might true might f...
#
#                            label
# 0  Not Hate and Offensive Speech
# 1      Offensive Speech Detected
# 2      Offensive Speech Detected
# 3      Offensive Speech Detected
# 4      Offensive Speech Detected

# %%
x = df['tweet']
y = df['label']
cv = CountVectorizer()
x = cv.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 50)

clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(x_test)
y_pred
# Out:
# array(['Offensive Speech Detected', 'Offensive Speech Detected',
#        'Hate Speech Detected', ..., 'Offensive Speech Detected',
#        'Offensive Speech Detected', 'Offensive Speech Detected'],
#       dtype=object)

# %%
clf.score(x_test, y_test)
# Out:
# 0.8759330240064556

# %%
test_data = ["I will fuck you"]
df = cv.transform(test_data).toarray()
clf.predict(df)
# Out:
# array(['Offensive Speech Detected'], dtype=object)
